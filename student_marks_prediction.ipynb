# %% [markdown]
# <a href="https://colab.research.google.com/github/ansar-mazhar/students_marks_prediction/blob/main/student_marks_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Business Problem Software for students marks prediction based on studying hours

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
path = r"/content/Dataset.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2          NaN          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %% [markdown]
# # Discover and visualize data to gain insights

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#        study_hours  student_marks
# count   195.000000      200.00000
# mean      6.995949       77.93375
# std       1.253060        4.92570
# min       5.010000       68.57000
# 25%       5.775000       73.38500
# 50%       7.120000       77.71000
# 75%       8.085000       82.32000
# max       8.990000       86.99000

# %%
plt.scatter(x=df.study_hours, y=df.student_marks)
plt.xlabel("Students Study Hours")
plt.ylabel("Students Marks")
plt.title("Scatter plot of Study Hours Vs Student Marks")
plt.show()

# %% [markdown]
# # Prepare the data for Machine Learning Algorithm

# %%
# Data Cleaning
df.isnull().sum()
# Out:
# study_hours      5
# student_marks    0
# dtype: int64

# %%
df.mean()
# Out:
# study_hours       6.995949
# student_marks    77.933750
# dtype: float64

# %%
df2 = df.fillna(df.mean())

# %%
df2.isnull().sum()
# Out:
# study_hours      0
# student_marks    0
# dtype: int64

# %% [markdown]
# # Split Dataset

# %%
x = df2.drop("student_marks", axis = "columns")
y = df2.drop("study_hours", axis = "columns")
print("Shape of X is: ", x.shape)
print("Shape of Y is: ", y.shape)
# Out:
# Shape of X is:  (200, 1)
# Shape of Y is:  (200, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=51)
print("Shape of X_train is: ", X_train.shape)
print("Shape of Y_train is: ", Y_train.shape)
print("Shape of X_test is: ", X_test.shape)
print("Shape of Y_test is: ", Y_test.shape)
# Out:
# Shape of X_train is:  (160, 1)
# Shape of Y_train is:  (160, 1)
# Shape of X_test is:  (40, 1)
# Shape of Y_test is:  (40, 1)

# %% [markdown]
# # Select a model and trian on it

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[3.93571802]])

# %%
lr.intercept_
# Out:
# array([50.44735504])

# %%
m = 3.93
c = 50.44
print("Enter Hours: ")
hours_study = float(input())
marks = m*hours_study + c
# Out:
# Enter Hours:
# 3

# %%
lr.predict([[4]])[0][0].round(2)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 66.19

# %%
y_predict = lr.predict(X_test)
y_predict
# Out:
# array([[83.11381458],
#        [78.9025963 ],
#        [84.57003024],
#        [85.82946001],
#        [84.72745896],
#        [80.75238377],
#        [72.84159055],
#        [71.66087515],
#        [73.23516235],
#        [71.66087515],
#        [73.47130543],
#        [76.38373677],
#        [73.23516235],
#        [73.58937697],
#        [82.95638585],
#        [70.40144538],
#        [73.23516235],
#        [78.74516758],
#        [75.55723598],
#        [82.68088559],
#        [76.65923703],
#        [70.48015974],
#        [74.77009238],
#        [77.98143645],
#        [85.59331693],
#        [82.56281405],
#        [76.42309395],
#        [85.0423164 ],
#        [78.39095296],
#        [81.38209865],
#        [81.73631327],
#        [83.15317176],
#        [82.20859943],
#        [81.10659839],
#        [73.58937697],
#        [71.1492318 ],
#        [71.89701823],
#        [81.53952737],
#        [72.60544747],
#        [71.93637541]])

# %%
pd.DataFrame(np.c_[X_test, Y_test, y_predict], columns = ["Study Hours", "Student Marks Actual", "Student Marks Predicted"])
# Out:
#     Study Hours  Student Marks Actual  Student Marks Predicted
# 0      8.300000                 82.02                83.113815
# 1      7.230000                 77.55                78.902596
# 2      8.670000                 84.19                84.570030
# 3      8.990000                 85.46                85.829460
# 4      8.710000                 84.03                84.727459
# 5      7.700000                 80.81                80.752384
# 6      5.690000                 73.61                72.841591
# 7      5.390000                 70.90                71.660875
# 8      5.790000                 73.14                73.235162
# 9      5.390000                 73.02                71.660875
# 10     5.850000                 75.02                73.471305
# 11     6.590000                 75.37                76.383737
# 12     5.790000                 74.44                73.235162
# 13     5.880000                 73.40                73.589377
# ...

# %% [markdown]
# # Fine Tune Test

# %%
lr.score(X_test, Y_test)*100
# Out:
# 95.14124242154466

# %% [markdown]
# # Save ML Model

# %%
import joblib
joblib.dump(lr, "Students_marks_prediction_model.pkl")
# Out:
# ['Students_marks_prediction_model.pkl']
